# %% [markdown]
# <a href="https://colab.research.google.com/github/JulianPonirakis/Stock-Price-Viz/blob/main/Stock_Price_Viz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git config --global user.email "jponirakis@gmail.com"
# !git config --global user.name "JulianPonirakis"

# %%
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/.git/

# %%
# Step 1: Initialize Git in the Colab environment
# !git init

# Step 2: Set up your Git identity (name and email)
# !git config --global user.email "jponirakis@gmail.com"
# !git config --global user.name "JulianPonirakis"

# Step 3: Add the GitHub repository remote
# !git remote add origin https://github.com/JulianPonirakis/Stock-Price-Viz.git

# Step 4: Check if the notebook is in the current directory
# !ls

# Step 5: Add the Colab notebook to Git (replace with correct path if needed)
# !git add Stock_Price_Viz.ipynb

# Step 6: Commit the changes
# !git commit -m "Initial commit using Colab"

# Step 7: Push to the GitHub repository
# !git push -u origin main
# Out:
# Reinitialized existing Git repository in /content/.git/
# error: remote origin already exists.
# sample_data
# fatal: pathspec 'Stock_Price_Viz.ipynb' did not match any files
# On branch master
#
# Initial commit
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	.config/
# 	sample_data/
#
# nothing added to commit but untracked files present (use "git add" to track)
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/JulianPonirakis/Stock-Price-Analysis-Visualization.git'

# %%
# Install libraries for stock analysis and visualization
# !pip install yfinance pandas matplotlib

# %%
# Import necessary libraries
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Download stock data for Apple (AAPL) from 2020-01-01 to 2023-01-01
stock_data = yf.download('AAPL', start='2020-01-01', end='2023-01-01')

# Plot the Closing Price of Apple
plt.figure(figsize=(10,6))
plt.plot(stock_data['Close'], label='AAPL Close Price')
plt.title('Apple Stock Price (Jan 2020 - Jan 2023)')
plt.xlabel('Date')
plt.ylabel('Price in USD')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
